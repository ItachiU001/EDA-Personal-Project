# %% [markdown]
# ## Attributes for both student-mat.csv (Math course) and student-por.csv (Portuguese language course) datasets:
# 1. school - student's school (binary: "GP" - Gabriel Pereira or "MS" - Mousinho da Silveira)
# 2. sex - student's sex (binary: "F" - female or "M" - male)
# 3. age - student's age (numeric: from 15 to 22)
# 4. address - student's home address type (binary: "U" - urban or "R" - rural)
# 5. famsize - family size (binary: "LE3" - less or equal to 3 or "GT3" - greater than 3)
# 6. Pstatus - parent's cohabitation status (binary: "T" - living together or "A" - apart)
# 7. Medu - mother's education (numeric: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# 8. Fedu - father's education (numeric: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# 9. Mjob - mother's job (nominal: "teacher", "health" care related, civil "services" (e.g. administrative or police), "at_home" or "other")
# 10. Fjob - father's job (nominal: "teacher", "health" care related, civil "services" (e.g. administrative or police), "at_home" or "other")
# 11. reason - reason to choose this school (nominal: close to "home", school "reputation", "course" preference or "other")
# 12. guardian - student's guardian (nominal: "mother", "father" or "other")
# 13. traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
# 14. studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
# 15. failures - number of past class failures (numeric: n if 1<=n<3, else 4)
# 16. schoolsup - extra educational support (binary: yes or no)
# 17. famsup - family educational support (binary: yes or no)
# 18. paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# 19. activities - extra-curricular activities (binary: yes or no)
# 20. nursery - attended nursery school (binary: yes or no)
# 21. higher - wants to take higher education (binary: yes or no)
# 22. internet - Internet access at home (binary: yes or no)
# 23. romantic - with a romantic relationship (binary: yes or no)
# 24. famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# 25. freetime - free time after school (numeric: from 1 - very low to 5 - very high)
# 26. goout - going out with friends (numeric: from 1 - very low to 5 - very high)
# 27. Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# 28. Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# 29. health - current health status (numeric: from 1 - very bad to 5 - very good)
# 30. absences - number of school absences (numeric: from 0 to 93)
#
# ## The grades are related with the course subject, Math or Portuguese:
# 31. G1 - first period grade (numeric: from 0 to 20)
# 31. G2 - second period grade (numeric: from 0 to 20)
# 32. G3 - final grade (numeric: from 0 to 20, output target)

# %%
## Importing all the libraries and packages

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf
py.offline.init_notebook_mode(connected=True) #Turning on notebook mode 
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
# ...

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None) #setup for whole data display

# %%
stud_m=pd.read_csv("student-mat.csv",sep=";") # Read dataset 1 using pandas
stud_m
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %%
stud_p=pd.read_csv("student-por.csv",sep=";") # Read dataset 2 using pandas
stud_p
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %%
#stud_combine=pd.merge(stud_p,stud_m,how='outer',on=None) 
#stud_combine

# %%
#stud_combine.info()

# %%
#stud_combine.duplicated().sum()

# %%
#stud_combine.isnull().sum()

# %%
stud_m.school.value_counts() # Total number of students from each school in dataset 1
# Out:
# GP    349
# MS     46
# Name: school, dtype: int64

# %%
stud_p.school.value_counts() # Total number of students from each school in dataset 2
# Out:
# GP    423
# MS    226
# Name: school, dtype: int64

# %%
#pd.set_option("display.max_rows", None, "display.max_columns", None)
#df_cat2 = pd.concat([stud_p,stud_m], axis=1)
#df_cat2

# %% [markdown]
# # As a part of personal project I am going to analyse the "student-por" (Portuguese language course) dataset

# %%
stud_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
stud_p.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %% [markdown]
# In the dataset;
# 1. The average age group is 16 years
# 2. The average final grade is 12 and the maximum is 19

# %%
stud_p.school.value_counts().iplot(kind="bar",xTitle="School Name",yTitle="#Count")
# Out:
# <div>                            <div id="0282a015-d5b1-4d01-8f4c-f0a4e261ce21" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# In the dataset;
# 1. More students have enrolled for the Portuguese language course of Gabriel Pereira school than Mousinho da Silveira school

# %%
stud_p.sex.value_counts().plot.pie(figsize=(10,5),fontsize = 14, autopct = '%.2f')
# Out:
# <AxesSubplot:ylabel='sex'>

# %% [markdown]
# In a dataset; 60:40 ratio is seen for Female:Male

# %%
grade_cols = ['G1','G2','G3']

i=0

while i<3:

    fig = plt.figure(figsize=[15,10])
    
    plt.subplot(2,2,1)
    sns.boxplot(x=grade_cols[i], data=stud_p)
    i=i+1
    
    plt.subplot(2,2,2)
    sns.boxplot(x=grade_cols[1], data=stud_p)
    i=i+1
    
    plt.subplot(2,2,3)
    sns.boxplot(x=grade_cols[2], data=stud_p)
    i=i+1
    
    plt.show()

# %% [markdown]
# 1. We can observe some skewness in a grade due to presence of outliers
# 2. The average grade of G3 is more than G1 & G2

# %%
Grades=stud_p[["G1","G2","G3"]]
Grades.nunique()
# Out:
# G1    17
# G2    16
# G3    17
# dtype: int64

# %%
Grades.iplot(kind="box")
# Out:
# <div>                            <div id="663306ef-ed09-474d-b3b0-d1b0b8e662c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Grades.nunique().plot.pie(figsize=(10,5),fontsize = 14, autopct = '%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
Grades.nunique().iplot(kind="bar",xTitle="Grades",yTitle="#Count")
# Out:
# <div>                            <div id="63db6c5d-4ae9-424d-bd05-107cd2efcdb2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Grades["G1"].value_counts().iplot(kind="bar",xTitle="G1-Grades",yTitle="#Count")
# Out:
# <div>                            <div id="e500f0a3-3b40-4caa-a4a8-5ebae0404cd5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Grades["G2"].value_counts().iplot(kind="bar",xTitle="G2-Grades",yTitle="#Count")
# Out:
# <div>                            <div id="3796dc5f-1138-474b-b0e0-6a983fe676d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Grades["G3"].value_counts().iplot(kind="bar",xTitle="G3-Grades",yTitle="#Count")
# Out:
# <div>                            <div id="faaa74ad-294a-4b01-a4e8-2436e92b63f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
stud_p.address.value_counts()
# Out:
# U    452
# R    197
# Name: address, dtype: int64

# %%
Address=stud_p.groupby(by="address")

# %%
Address.G1.mean().sort_values(ascending=False).iplot(kind="bar")
# Out:
# <div>                            <div id="f8b254d0-4a6b-4b63-baca-23e1dce81b1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Address.G2.mean().sort_values(ascending=False).iplot(kind="bar")
# Out:
# <div>                            <div id="4456c33e-f44f-460f-aaef-b3f4e2d4f074" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Address.G3.mean().sort_values(ascending=False).iplot(kind="bar")
# Out:
# <div>                            <div id="09cde275-b0e5-4cc6-ba12-c17549a3393d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Address.G3.value_counts().iplot(kind="bar")
# Out:
# <div>                            <div id="8c3a5fef-93b6-439f-b1d4-c9883945f13b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# Dataset is group by address and sort by grades; from above analysis;
# 1. The students from Urban area has good average grades that rural area

# %%
stud_p.studytime.value_counts()
# Out:
# 2    305
# 1    212
# 3     97
# 4     35
# Name: studytime, dtype: int64

# %%
Stud_Study_Time=stud_p.groupby(by="studytime")
Stud_Study_Time.G3.value_counts().iplot(kind="bar")
# Out:
# <div>                            <div id="3b956cbb-6a38-454a-b698-eeb45d605bce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Stud_Study_Time.G3.nunique().iplot(kind="bar")
# Out:
# <div>                            <div id="903f51ed-3075-4856-9eda-1b934fa565ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Stud_Study_Time.failures.value_counts().iplot(kind="bar")
# Out:
# <div>                            <div id="66acd2c2-bc3c-4d99-af55-25dffb7a7b75" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# There is negative correlation between study time and the failures

# %%
Stud_Study_Time.failures.unique()
# Out:
# studytime
# 1    [0, 3, 1, 2]
# 2    [0, 1, 2, 3]
# 3       [0, 1, 2]
# 4          [0, 1]
# Name: failures, dtype: object

# %%
Stud_Study_Time.failures.value_counts()
# Out:
# studytime  failures
# 1          0           163
#            1            36
#            3             9
#            2             4
# 2          0           264
#            1            26
#            2            10
#            3             5
# 3          0            89
#            1             6
#            2             2
# 4          0            33
#            1             2
# Name: failures, dtype: int64

# %%
#sns.pairplot(stud_p)

# %%
stud_p.Pstatus.value_counts()
# Out:
# T    569
# A     80
# Name: Pstatus, dtype: int64

# %%
sns.relplot(x=stud_p.Dalc,y=stud_p.absences,hue=stud_p.health)

# %% [markdown]
# In a workday, moderate alcohol consumption will affect the health and cause the absentisam in the school

# %%
'''
d1=read.table("student-mat.csv",sep=";",header=TRUE)
d2=read.table("student-por.csv",sep=";",header=TRUE)
d3=merge(d1,d2,by=c("school","sex","age","address","famsize","Pstatus","Medu","Fedu","Mjob","Fjob","reason","nursery","internet"))
print(nrow(d3)) # 382 students
'''
# Out:
# '\nd1=read.table("student-mat.csv",sep=";",header=TRUE)\nd2=read.table("student-por.csv",sep=";",header=TRUE)\nd3=merge(d1,d2,by=c("school","sex","age","address","famsize","Pstatus","Medu","Fedu","Mjob","Fjob","reason","nursery","internet"))\nprint(nrow(d3)) # 382 students\n'
